# %%
from tqdm import tqdm
import numpy as np
import pandas as pd

from sklearn.decomposition import PCA

import matplotlib.pyplot as plt
import seaborn as sns
import seaborn.objects as so
import plotly.express as px

# %%
items_meta = pd.read_parquet(f'data/items_meta.parquet.gzip')

# %%
embeddings = np.stack(items_meta.embeddings.values, axis=0)

# %%
# Распределение в эмбедингах

# %%
p = so.Plot(embeddings.min(axis=1)).add(so.Area(), so.KDE(bw_adjust=0.25))
p.label(title='Распределение минимумов', x='min', y='count')

# %%
p = so.Plot(embeddings.max(axis=1)).add(so.Area(), so.KDE(bw_adjust=0.25))
p.label(title='Распределение максимумов', x='max', y='count')

# %% [markdown]
# ### Feature reduction

# %%
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from umap import UMAP
import umap

# %%
pca = PCA(n_components=4)
X_pca = pca.fit(np.transpose(embeddings))

# %%
df_pca = pd.DataFrame(np.transpose(X_pca.components_), 
                      # columns=['pca_1', 'pca_2', 'pca_3', 'pca_4']
                     )

# %%
sns.pairplot(df_pca, height=2, plot_kws={'s': 1});

# %%
from numba import njit
njit(parallel=True)(lambda A: 2*A)(np.ones(3))
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# array([2., 2., 2.])

# %%
ump = umap.UMAP(n_components=5)
X_umap = ump.fit(embeddings)

# %%
df_umap = pd.DataFrame(X_umap.embedding_, 
                       # columns=['ump_1', 'ump_2', 'ump_3', 'ump_4']
                      )

# %%
sns.pairplot(df_umap, height=2, plot_kws={'s': 1});

# %%
# #### 3D plot

# fig = px.scatter_3d(x=pca.components_[0], y=pca.components_[1], z=pca.components_[2])
# fig.update_traces(marker_size = 1)
# fig.update_layout(
#     margin=dict(l=10, r=10, t=10, b=10),
# )
# fig.show()

# %%
z2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [16], line 1
# ----> 1 z2
#
# NameError: name 'z2' is not defined

# %% [markdown]
# ### Clusterization

# %%
from sklearn.metrics import rand_score, jaccard_score, adjusted_mutual_info_score, silhouette_score
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN

# %%
km = KMeans(3)
km.fit(X_tsne)

# %%
# ap = AgglomerativeClustering()
# ap.fit(X_tsne)

# %%
dbs = DBSCAN(eps=1.8, min_samples=4)
dbs.fit(X_tsne)

# %%
labels_ndarray of shape (n_samples,)
Labels of each point

inertia_float
